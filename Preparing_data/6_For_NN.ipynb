# %% [markdown]
# # Подготовка данных к обучению на нейронной сети

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Открытие данных

# %%
df = pd.read_csv('../clean_categorizated_data_without_outliers_with_coordinates_and_amenities.csv', sep=';')

# %%
df.sample(3)
# Out:
#       number of rooms  area of apartment  number of floors  apartment floor  \
# 581                 3              158.0                10                8
# 1752                3               97.7                 4                3
# 972                 3               78.5                25               24
#
#            price  year of construction  elevator  \
# 581   12500000.0                  2008       1.0
# 1752   5000000.0                  1957       1.0
# 972    5700000.0                  2019       1.0
#
#                                        full address  concierge  garbage chute  \
# 581   Пермский край, Пермь, проезд Якуба Коласа, 11          1              0
# 1752            Пермь, улица Космонавта Леонова, 23          0              0
# 972   Пермский край, Пермь, ул. Красные Казармы, 64          0              0
#
#       ...  parking_открытая во дворе  parking_наземная многоуровневая  \
# 581   ...                        0.0                              0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767 entries, 0 to 1766
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number of rooms                  1767 non-null   int64
#  1   area of apartment                1767 non-null   float64
#  2   number of floors                 1767 non-null   int64
#  3   apartment floor                  1767 non-null   int64
#  4   price                            1767 non-null   float64
#  5   year of construction             1767 non-null   int64
#  6   elevator                         1767 non-null   float64
#  7   full address                     1767 non-null   object
#  8   concierge                        1767 non-null   int64
#  9   garbage chute                    1767 non-null   int64
#  10  repair_дизайнерский              1767 non-null   float64
#  11  repair_евро                      1767 non-null   float64
# ...

# %% [markdown]
# ## Удаление из данных полного адреса

# %%
df = df.drop('full address', axis=1)

# %% [markdown]
# ## Приведение типов к float32

# %%
df = df.astype(np.float32)

# %% [markdown]
# ## Удаление признака парковки

# %%
df = df.drop(['parking_за шлагбаумом во дворе', 'parking_открытая во дворе', 
              'parking_наземная многоуровневая', 'parking_подземная'], axis=1)

# %% [markdown]
# ## Итоги подготовки данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767 entries, 0 to 1766
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   number of rooms             1767 non-null   float32
#  1   area of apartment           1767 non-null   float32
#  2   number of floors            1767 non-null   float32
#  3   apartment floor             1767 non-null   float32
#  4   price                       1767 non-null   float32
#  5   year of construction        1767 non-null   float32
#  6   elevator                    1767 non-null   float32
#  7   concierge                   1767 non-null   float32
#  8   garbage chute               1767 non-null   float32
#  9   repair_дизайнерский         1767 non-null   float32
#  10  repair_евро                 1767 non-null   float32
#  11  repair_косметический        1767 non-null   float32
#  12  repair_требует ремонта      1767 non-null   float32
# ...

# %%
df.sample(3)
# Out:
#      number of rooms  area of apartment  number of floors  apartment floor  \
# 60               2.0          47.000000               5.0              3.0
# 67               2.0          44.400002               5.0              1.0
# 385              3.0          88.000000              15.0              3.0
#
#          price  year of construction  elevator  concierge  garbage chute  \
# 60   2150000.0                1965.0       0.0        0.0            0.0
# 67   2650000.0                1970.0       0.0        0.0            0.0
# 385  5999000.0                1995.0       1.0        0.0            1.0
#
#      repair_дизайнерский  ...  district_Мотовилихинский  \
# 60                   0.0  ...                       0.0
# 67                   0.0  ...                       0.0
# 385                  0.0  ...                       0.0
#
#      district_Орджоникидзевский  district_Свердловский        lat        lon  \
# ...

# %%
df.to_csv('../final_data.csv', sep=';', index=False)

# %% [markdown]
# __В ходе шестой обработки были:__
# 1. отброшены не числовый признаки
# 2. все числовые признаки были приведены к типу float
# После испытаний были:
# 1. удалены признаки парковки
